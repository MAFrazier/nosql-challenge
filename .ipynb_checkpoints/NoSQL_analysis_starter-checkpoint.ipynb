# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
hygiene_20 = establishments.count_documents(query)
   
# Display the first document in the results using pprint

results = establishments.find(query)
print (hygiene_20)
print("")
print("First document:")
print("-------------------------------")
pprint(results[0])
# Out:
# 41
#
# First document:
# -------------------------------
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('659cad7708dcac7477806336'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame

hygiene =establishments.find(query)
hygiene_df = pd.DataFrame(hygiene)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(hygiene_df))

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# Rows in DataFrame:  41
#                         _id   FHRSID  ChangesByServerID  \
# 0  659cad7708dcac7477806336   110681                  0
# 1  659cad7808dcac74778066b3   612039                  0
# 2  659cad7808dcac74778069c4   730933                  0
# 3  659cad7808dcac7477806bac   172735                  0
# 4  659cad7808dcac7477806bbb   172953                  0
# 5  659cad7808dcac747780755d   512854                  0
# 6  659cad7808dcac747780777c  1537089                  0
# 7  659cad7908dcac7477808ca7   155648                  0
# 8  659cad7908dcac74778090ee  1012883                  0
# 9  659cad7a08dcac74778098fe   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
distinct_local_authorities = establishments.distinct('LocalAuthorityName')
print("Distinct Local Authorities:", distinct_local_authorities)
# Out:
# Distinct Local Authorities: ['Aberdeenshire', 'Arun', 'Ashford', 'Babergh', 'Barking and Dagenham', 'Basildon', 'Bexley', 'Braintree', 'Brentwood', 'Bromley', 'Broxbourne', 'Canterbury City', 'Castle Point', 'Chelmsford', 'City of London Corporation', 'Colchester', 'Dartford', 'Dorset', 'East Hertfordshire', 'East Renfrewshire', 'East Suffolk', 'Eastbourne', 'Epping Forest', 'Folkestone and Hythe', 'Gravesham', 'Greenwich', 'Hackney', 'Harlow', 'Hastings', 'Havering', 'Ipswich', 'Kensington and Chelsea', 'Knowsley', 'Lambeth', 'Lewes', 'Lewisham', 'Maidstone', 'Maldon', 'Medway', 'Mid Sussex', 'Newham', 'North Hertfordshire', 'North Norfolk', 'Orkney Islands', 'Pendle', 'Reading', 'Redbridge', 'Rochford', 'Rother', 'Rushmoor', 'Salford', 'Sevenoaks', 'Slough', 'South Cambridgeshire', 'Southend-On-Sea', 'Spelthorne', 'Stratford-on-Avon', 'Sunderland', 'Swale', 'Tandridge', 'Tendring', 'Thanet', 'Thurrock', 'Tonbridge and Malling', 'Tower Hamlets', 'Tunbridge Wells', 'Uttlesford', 'Waltham Forest', 'Wealden', 'West Suffolk', 'York']

# %%
query = {"LocalAuthorityName": "City of London Corporation"}

# Count the number of documents with 'LocalAuthorityName' as 'City of London Corporation'
result = establishments.count_documents(query)
print (result)

results = establishments.find(query)
pprint (results[0])
# Out:
# 37
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('659cad7908dcac7477807d53'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
query = {"RatingValue": {'$gte':4}}

# Count the number of documents with 'LocalAuthorityName' as 'City of London Corporation'
result = establishments.count_documents(query)


print(result)
# Out:
# 1

# %%
# Define the first part of the query with $regex
regex = {"LocalAuthorityName": {'$regex': 'London'}}
gte = {"RatingValue": {'$gte': 4}}

query = {**regex, **gte}

# Run the first part of the query
results_regex = establishments.find(regex)

# Run the second part of the query
results_gte = establishments.find(gte)

# Run the full query
results = establishments.find(query)


# Print the results
print("Results for the first part (regex):")
for result in results_regex:
    print(result)
    
print("--------------------------------------------------------------------------------")

print("\nResults for the second part (RatingValue >= 4):")
for result in results_gte:
    print(result)
print("--------------------------------------------------------------------------------")

print("\nResults for the full query:")
for result in results:
    print(result)
# Out:
# Results for the first part (regex):
# {'_id': ObjectId('659cad7908dcac7477807d53'), 'FHRSID': 621707, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000025307', 'BusinessName': "Charlie's", 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks', 'AddressLine2': 'Sheppy Kent', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'ME12', 'Phone': '', 'RatingValue': '4', 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2021-10-18T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.508551, 'latitude': 51.369321}, 'RightToReply': '', 'Distance': 4627.439467780196, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/621707'}]}
# {'_id': ObjectId('659cad7908dcac7477808083'), 'FHRSID': 1130836, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000034075', 'BusinessName': 'Mv City Cruises Erasmus', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Cherry Garden Pier', 'AddressLine2': 'Cherry Garden Street Rotherhithe', 'AddressLine3': 'Charlton', 'AddressLine4': '', 'PostCode': 'TN4 8HR', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-05-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.249255999922752, 'latitude': 51.1236228942871}, 'RightToReply': '', 'Distance': 4627.8731788858, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1130836'}]}
# {'_id': ObjectId('659cad7908dcac7477808bc0'), 'FHRSID': 293783, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000002614', 'BusinessName': 'Benfleet Motor Yacht Club', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Ferry Road', 'AddressLine2': 'South Benfleet Essex', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'SS7 1NF', 'Phone': '', 'RatingValue': '4', 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2018-11-02T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.561954, 'latitude': 51.543831}, 'RightToReply': '', 'Distance': 4631.968418191259, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/293783'}]}
# {'_id': ObjectId('659cad7908dcac74778091cd'), 'FHRSID': 1523645, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000038853', 'BusinessName': 'Gourmet Kitchen', 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844, 'AddressLine1': '1 London Gateway', 'AddressLine2': 'London Gateway Drive Stanford-Le-Hope', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'SS17 9DY', 'Phone': '', 'RatingValue': '3', 'RatingKey': 'fhrs_3_en-gb', 'RatingDate': '2022-05-05T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.4596371, 'latitude': 51.5100659}, 'RightToReply': '', 'Distance': 4634.42812137316, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1523645'}]}
# {'_id': ObjectId('659cad7a08dcac74778099bf'), 'FHRSID': 294474, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000014647', 'BusinessName': 'Tilbury Seafarers Centre', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Tenants Row Tilbury Docks', 'AddressLine2': 'Tilbury Essex', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'RM18 7EH', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-11-02T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.346325, 'latitude': 51.464078}, 'RightToReply': '', 'Distance': 4636.847649796817, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294474'}]}
# {'_id': ObjectId('659cad7a08dcac74778099c0'), 'FHRSID': 1315095, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000036464', 'BusinessName': 'Coombs Catering t/a The Lock and Key', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Leslie Ford House', 'AddressLine2': 'Tilbury', 'AddressLine3': 'Charlton', 'AddressLine4': '', 'PostCode': 'RM18 7EH', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2020-12-04T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.346336990594864, 'latitude': 51.4640655517578}, 'RightToReply': '', 'Distance': 4636.846754121153, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1315095'}]}
# {'_id': ObjectId('659cad7a08dcac747780a0c9'), 'FHRSID': 294900, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000019066', 'BusinessName': 'Mv Valulla', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Reeds River Cruises LtdKings ReachRiver ThamesSouthwark', 'AddressLine2': 'London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'RM15 5QY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2016-08-23T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.287555, 'latitude': 51.504071}, 'RightToReply': '', 'Distance': 4640.460834256174, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294900'}]}
# {'_id': ObjectId('659cad7c08dcac747780c1d6'), 'FHRSID': 1252616, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000035653', 'BusinessName': 'Froottree', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Tereza Joanne King George V Lock', 'AddressLine2': 'Woolwich Manor Way London', 'AddressLine3': 'Charlton', 'AddressLine4': '', 'PostCode': 'E16 2NJ', 'Phone': '', 'RatingValue': None, 'RatingKey': 'fhrs_awaitinginspection_en-gb', 'RatingDate': '1901-01-01T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': None, 'Structural': None, 'ConfidenceInManagement': None}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0693250000476837, 'latitude': 51.5011100769043}, 'RightToReply': '', 'Distance': 4648.300000043045, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1252616'}]}
# {'_id': ObjectId('659cad7c08dcac747780c1df'), 'FHRSID': 293756, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000002538', 'BusinessName': 'Tereza Joanne', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Funcraft UK Ltd King George V Dock Woolwich Manor Way', 'AddressLine2': 'London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2NJ', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-07-09T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.069286, 'latitude': 51.501121}, 'RightToReply': '', 'Distance': 4648.301822363946, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/293756'}]}
# {'_id': ObjectId('659cad7c08dcac747780c5a1'), 'FHRSID': 878523, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000029844', 'BusinessName': 'Brick Lane Brews', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Air side London City Airport', 'AddressLine2': 'London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PX', 'Phone': '', 'RatingValue': '4', 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2019-01-18T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.048006, 'latitude': 51.503733}, 'RightToReply': '', 'Distance': 4649.1734848484375, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/878523'}]}
# {'_id': ObjectId('659cad7c08dcac747780c5a5'), 'FHRSID': 902473, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000029852', 'BusinessName': 'Pret A Manger', 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844, 'AddressLine1': 'Retail Unit 2 Gate 3', 'AddressLine2': 'West Pier London City Airport', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PX', 'Phone': '', 'RatingValue': '2', 'RatingKey': 'fhrs_2_en-gb', 'RatingDate': '2021-12-06T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 15, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.048006, 'latitude': 51.503733}, 'RightToReply': '', 'Distance': 4649.1734848484375, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/902473'}]}
# {'_id': ObjectId('659cad7c08dcac747780c5bb'), 'FHRSID': 295107, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000020749', 'BusinessName': 'City Bar & Grill', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'London City Airport (Airside)', 'AddressLine2': 'London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PX', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-12-06T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0479655750095844, 'latitude': 51.5041122436523}, 'RightToReply': '', 'Distance': 4649.188850403149, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/295107'}]}
# {'_id': ObjectId('659cad7c08dcac747780c5be'), 'FHRSID': 295105, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000020747', 'BusinessName': 'Cabin Bar', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'London City Airport', 'AddressLine2': 'Airside Outside Ledger Building London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PX', 'Phone': '', 'RatingValue': '2', 'RatingKey': 'fhrs_2_en-gb', 'RatingDate': '2022-06-30T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 10, 'Structural': 15, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.047966, 'latitude': 51.504112}, 'RightToReply': '', 'Distance': 4649.188825980348, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/295105'}]}
# {'_id': ObjectId('659cad7c08dcac747780c5cc'), 'FHRSID': 293772, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000002585', 'BusinessName': 'The Nuance Group (UK) Limited', 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613, 'AddressLine1': 'Duty Free Shop Passenger Terminal', 'AddressLine2': 'London City AirportRoyal DocksLondon', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PX', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2017-07-17T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.047966, 'latitude': 51.504112}, 'RightToReply': '', 'Distance': 4649.188825980348, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/293772'}]}
# {'_id': ObjectId('659cad7c08dcac747780c5ce'), 'FHRSID': 294606, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000016185', 'BusinessName': 'WH Smith', 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613, 'AddressLine1': 'London City Airport', 'AddressLine2': 'Silvertown London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PX', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2017-07-17T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0479655750095844, 'latitude': 51.5041122436523}, 'RightToReply': '', 'Distance': 4649.188850403149, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294606'}]}
# {'_id': ObjectId('659cad7c08dcac747780c798'), 'FHRSID': 294523, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000015222', 'BusinessName': 'Jet Centre', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'London City Airport', 'AddressLine2': 'Royal Docks London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PJ', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-02-11T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0405181497335434, 'latitude': 51.5048065185547}, 'RightToReply': '', 'Distance': 4649.48586971274, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294523'}]}
# {'_id': ObjectId('659cad7c08dcac747780c79a'), 'FHRSID': 294616, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000016269', 'BusinessName': 'Caffè Nero', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'London City Airport Airside Departure Lounge', 'AddressLine2': 'Royal Docks London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 2PJ', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-11-12T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.040518, 'latitude': 51.504808}, 'RightToReply': '', 'Distance': 4649.485929427517, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/294616'}]}
# {'_id': ObjectId('659cad7c08dcac747780ca3d'), 'FHRSID': 1427985, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000037871', 'BusinessName': 'Mv Sunborn Yacht Hotel', 'BusinessType': 'Hotel/bed & breakfast/guest house', 'BusinessTypeID': 7842, 'AddressLine1': 'Western Gateway', 'AddressLine2': 'Royal Victoria Dock', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 1XL', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-11-19T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.027107, 'latitude': 51.50817}, 'RightToReply': '', 'Distance': 4650.0981296859945, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1427985'}]}
# {'_id': ObjectId('659cad7c08dcac747780cc44'), 'FHRSID': 934211, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000030457', 'BusinessName': 'Good Hotel London', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Western Gateway Royal Victoria Dock', 'AddressLine2': 'Floating Platform next to Emirates Cable Car', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E16 1FA', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-07-16T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.01792, 'latitude': 51.507681}, 'RightToReply': '', 'Distance': 4650.415301460256, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/934211'}]}
# {'_id': ObjectId('659cad7c08dcac747780cc6b'), 'FHRSID': 1392440, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000037382', 'BusinessName': 'La Nonna lina', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Dock Road', 'AddressLine2': 'London', 'AddressLine3': 'Charlton', 'AddressLine4': '', 'PostCode': 'E16 1AG', 'Phone': '', 'RatingValue': '4', 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2021-10-01T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 10, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0157549995929003, 'latitude': 51.5059814453125}, 'RightToReply': '', 'Distance': 4650.4320658321685, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1392440'}]}
# {'_id': ObjectId('659cad7c08dcac747780cc72'), 'FHRSID': 558640, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000024155', 'BusinessName': 'Wake Up Docklands Limited', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Western Beach Royal Victoria Docks', 'AddressLine2': 'London', 'AddressLine3': 'Charlton', 'AddressLine4': '', 'PostCode': 'E16 1AG', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-11-05T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.015742, 'latitude': 51.505992}, 'RightToReply': '', 'Distance': 4650.432926312135, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/558640'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce4b'), 'FHRSID': 1498024, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000038347', 'BusinessName': 'MV Venus Clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Trinity Buoy Wharf', 'AddressLine2': 'Orchard Place', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-02-25T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.00890800673629534, 'latitude': 51.507771887145}, 'RightToReply': '', 'Distance': 4650.747348950763, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1498024'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce7f'), 'FHRSID': 1090017, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033472', 'BusinessName': 'MV Moon clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers 3rd flr Clippers House', 'AddressLine2': 'Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-09-25T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0078159999102354, 'latitude': 51.5082588195801}, 'RightToReply': '', 'Distance': 4650.805001170512, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090017'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce82'), 'FHRSID': 1090022, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033478', 'BusinessName': 'MV Meteor clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090022'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce83'), 'FHRSID': 1090019, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033475', 'BusinessName': 'MV Tornado clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-05-02T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090019'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce84'), 'FHRSID': 1090018, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033473', 'BusinessName': 'MV Mercury clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers 3rd flr Clippers House', 'AddressLine2': 'Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0078159999102354, 'latitude': 51.5082588195801}, 'RightToReply': '', 'Distance': 4650.805001170512, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090018'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce85'), 'FHRSID': 1090027, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033483', 'BusinessName': 'MV Cyclone clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090027'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce86'), 'FHRSID': 1090024, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033480', 'BusinessName': 'MV Galaxy clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-05-02T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090024'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce87'), 'FHRSID': 1090028, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033484', 'BusinessName': 'MV Neptune clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-05-02T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090028'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce88'), 'FHRSID': 1090025, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033481', 'BusinessName': 'MV Hurricane clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090025'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce89'), 'FHRSID': 1090016, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033470', 'BusinessName': 'MV Sun clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers 3rd flr Clippers House', 'AddressLine2': 'Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.0078159999102354, 'latitude': 51.5082588195801}, 'RightToReply': '', 'Distance': 4650.805001170512, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090016'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce8a'), 'FHRSID': 1090020, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033476', 'BusinessName': 'MV Typhoon clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090020'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce8b'), 'FHRSID': 1090023, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033479', 'BusinessName': 'MV Jupiter clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090023'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce8d'), 'FHRSID': 293758, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000002546', 'BusinessName': 'Mv Storm Clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2019-01-11T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/293758'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce8e'), 'FHRSID': 1450220, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000038259', 'BusinessName': 'Canary Wharf 1V', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Trinity Buoy Wharf', 'AddressLine2': '64 Orchard Place', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-02-25T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007815, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805044246847, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1450220'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce8f'), 'FHRSID': 1090021, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033477', 'BusinessName': 'MV Monsoon clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2018-12-14T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090021'}]}
# {'_id': ObjectId('659cad7d08dcac747780ce90'), 'FHRSID': 1090026, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000033482', 'BusinessName': 'MV Aurora clipper', 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Thames Clippers Unit 12 The Riverside Building', 'AddressLine2': '64 Orchard Place Trinity Buoy Wharf London', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'E14 0JY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-12-03T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.007816, 'latitude': 51.508259}, 'RightToReply': '', 'Distance': 4650.805007769328, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'http://api.ratings.food.gov.uk/establishments/1090026'}]}
# --------------------------------------------------------------------------------
#
# Results for the second part (RatingValue >= 4):
# {'_id': ObjectId('659cad7608dcac7477804805'), 'FHRSID': 647177, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000041489', 'BusinessName': 'Wear Bay Bowls Club', 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843, 'AddressLine1': 'Wear Bay Road', 'AddressLine2': 'Folkestone', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT19 6PY', 'Phone': '', 'RatingValue': 4, 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2014-03-31T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 1.196408, 'latitude': 51.086058}, 'RightToReply': '', 'Distance': 4591.821311183521, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}
# --------------------------------------------------------------------------------
#
# Results for the full query:

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName":{'$regex': 'London'}, "RatingValue" : {'$gte':4}}

# Use count_documents to display the number of documents in the result
London_Rating = establishments.count_documents(query)

# Display the first document in the results using pprint

results = establishments.find(query)
print (London_Rating)
print("")
if London_Rating > 0:
    print("First document:")
    print("-------------------------------")
    pprint(results1[0])
else:
    print("No documents found.")
# Out:
# 0
#
# No documents found.

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.0838400

query = {'geocode.latitude':{'$gte':latitude-degree_search,'$lte':latitude+degree_search},
        'geocode.longitude':{'$gte':longitude-degree_search,'$lte':longitude+degree_search},
        'RatingValue':'5'}
sort =  [('scores.Hygiene', 1)]
limit = 5

# Print the results
results = list(establishments.find(query).sort(sort).limit(limit))

pprint(results)
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('659cad7c08dcac747780bb96'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('659cad7c08dcac747780bbab'),
#   'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '17 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.975587048333,
#   'FHRSID': 909912,
#   'LocalAuthorityBusinessID': 'PI/000201100',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2020-10-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('659cad7c08dcac747780bbac'),
#   'geocode': {'latitude': 51.4871632, 'longitude': 0.0916256},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('659cad7c08dcac747780bb75'),
#   'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('659cad7c08dcac747780bb76'),
#   'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}]

# %%
# Convert result to Pandas DataFrame
RatingValue5 = list(establishments.find(query).sort(sort).limit(limit))
RatingValue5_DB = pd.DataFrame(RatingValue5)
RatingValue5_DB.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  659cad7c08dcac747780bb96   694609                  0
# 1  659cad7c08dcac747780bbab   695241                  0
# 2  659cad7c08dcac747780bbac   909912                  0
# 3  659cad7c08dcac747780bb75  1380578                  0
# 4  659cad7c08dcac747780bb76   695223                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 3                    14425  Howe and Co Fish and Chips - Van 17
# 4             PI/000178842                              Iceland
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                      Retailers - other            4613
# 3                         Mobile caterer            7846
# 4  Retailers - supermarkets/hypermarkets            7840
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1               Plumstead Manor School Old Mill Road
# 2                                   17 Lakedale Road
# 3  Restaurant And Premises 107A Plumstead High St...
# 4                    144 - 146 Plumstead High Street
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.09208, 'latitude': 51.4873437}
# 1  {'longitude': 0.0859939977526665, 'latitude': ...
# 2   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 3  {'longitude': 0.0925370007753372, 'latitude': ...
# 4  {'longitude': 0.0924199968576431, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.974010            False
# 2  4646.975587            False
# 3  4646.955931            False
# 4  4646.946071            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
zero_hygiene = {'$match': {'scores.Hygiene':0}}
# 2. Groups the matches by Local Authority
group = {'$group': {"_id" : "$LocalAuthorityName",
                   "count": {'$sum':1}}}
         
# 3. Sorts the matches from highest to lowest
sort =  {'$sort': { 'count': -1, '_id': 1 }}
pipeline = [zero_hygiene, group, sort]

results = list(establishments.aggregate(pipeline))
# Print the number of documents in the result
print(f"There are {len(results)} establishments with hygiene score of 0.")
print("------------------------------------------------------------------")
print("First 10 results")
print("")
# Print the first 10 results

pprint(results[0:10])
# Out:
# There are 55 establishments with hygiene score of 0.
# ------------------------------------------------------------------
# First 10 results
#
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_zero = list(establishments.aggregate(pipeline))
hygiene_zero_db = pd.DataFrame(hygiene_zero)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(hygiene_zero_db))
# Display the first 10 rows of the DataFrame
hygiene_zero_db.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
